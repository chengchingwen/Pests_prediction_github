# %%
import csv
import os
from bs4 import BeautifulSoup
def remove_99999(raw_data):
    di.remove(di[0])
    df.remove(df[0])
    print('完成')

    for row in df:
        if row[6] == str(99999):
            df.remove(row)

    for row in df:
        if row[6] == str(99999):
            df.remove(row)

    for row in df:
        if row[6] == str(99999):
            df.remove(row)
    return df

def read_data():
    with open('地區資訊new.csv', 'r') as f:  #opens PW file
        reader = csv.reader(f)
        di = list(list(rec) for rec in csv.reader(f, delimiter=',')) #reads csv into a list of lists
        f.close()

    with open('蔬果重要害蟲防疫旬報_東方果實蠅數據_new.csv','r') as f:
        reader = csv.reader(f)
        df = list(list(rec) for rec in csv.reader(f, delimiter=','))
        #data_fly
        f.close()
    return di, df

# %%
def write_gap_year(row_df):
    need_to_continue = 0
    filename = 'C:\\Users\Aaron\\weather\\' + row_df[0] + row_df[1] + str(int(row_df[2])-1) + str(12) + '.txt' 
    with open(filename,'r') as f:
        data = f.read()
        f.close()
    print('rrrr')
    sp = BeautifulSoup(data,'lxml')
    tra = sp.find_all('tr')
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    traa_count=0
    for traa in tra:
        traa_count = traa_count+1
        if traa_count <31 and traa_count>20:
            tda=traa.find_all('td')
            tdaa_count = 0
            for tdaa in tda:
                tdaa_count = tdaa_count +1
                if  tdaa_count == 1:
                    row_df.append(tdaa.text)
                if  tdaa_count == 8 or tdaa_count==9 or tdaa_count==11 or tdaa_count==18:
                    row_df.append(tdaa.text.replace('\xa0',''))
                    
    return row_df, need_to_continue

def write_gap_month(row_df):
    need_to_continue = 0
    filename = 'C:\\Users\Aaron\\weather\\' + row_df[0] + row_df[1] + row_df[2] + str(int(row_df[3])-1) + '.txt' 
    with open(filename,'r') as f:
        data = f.read()
        f.close()
    sp = BeautifulSoup(data,'lxml')
    tra = sp.find_all('tr')
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    traa_count=0
    for traa in tra:
        traa_count = traa_count+1
        if traa_count <31 and traa_count>20:
            tda=traa.find_all('td')
            tdaa_count = 0
            for tdaa in tda:
                tdaa_count = tdaa_count +1
                if  tdaa_count == 1:
                    row_df.append(tdaa.text)
                if  tdaa_count == 8 or tdaa_count==9 or tdaa_count==11 or tdaa_count==18:
                    row_df.append(tdaa.text.replace('\xa0',''))

    return row_df, need_to_continue

def write_2(row_df):
    need_to_continue = 0
    filename = 'C:\\Users\Aaron\\weather\\' + row_df[0] + row_df[1] + row_df[2] + row_df[3] + '.txt' 
    with open(filename,'r') as f:
        data = f.read()
        f.close()
    sp = BeautifulSoup(data,'lxml')
    tra = sp.find_all('tr')
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    traa_count=0
    for traa in tra:
        traa_count = traa_count+1
        if traa_count <11:
            tda=traa.find_all('td')
            tdaa_count = 0
            for tdaa in tda:
                tdaa_count = tdaa_count +1
                if  tdaa_count == 1:
                    row_df.append(tdaa.text)
                if  tdaa_count == 8 or tdaa_count==9 or tdaa_count==11 or tdaa_count==18:
                    row_df.append(tdaa.text.replace('\xa0',''))
    
    return row_df, need_to_continue

def write_3(row_df):
    need_to_continue = 0
    filename = 'C:\\Users\Aaron\\weather\\' + row_df[0] + row_df[1] + row_df[2] + row_df[3] + '.txt' 
    with open(filename,'r') as f:
        data = f.read()
        f.close()
    sp = BeautifulSoup(data,'lxml')
    tra = sp.find_all('tr')
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    traa_count=0
    for traa in tra:
        traa_count = traa_count+1
        if traa_count <21 and traa_count>10:
            tda=traa.find_all('td')
            tdaa_count = 0
            for tdaa in tda:
                tdaa_count = tdaa_count +1
                if  tdaa_count == 1:
                    row_df.append(tdaa.text)
                if  tdaa_count == 8 or tdaa_count==9 or tdaa_count==11 or tdaa_count==18:
                    row_df.append(tdaa.text.replace('\xa0',''))
    
    return row_df, need_to_continue
print('成功')
# Out:
# 成功

# %%
all_data = []
coun_di = 0
di, df = read_data()
di = di[1:]
data = df[1:]

for row_di in di:
    coun_di = coun_di + 1
    filename = ('C:\\Users\\Aaron\\weather\\東方果實蠅'+ row_di[0]+ row_di[1]+'.csv')
    print(filename)
    if os.path.isfile(filename):
        continue
    
    filename = ('C:\\Users\\Aaron\\weather\\'+ row_di[0]+ row_di[1]+'20131.txt')
    if not os.path.isfile(filename):
        break
    
    buffer = []
    for row_df in df:
        #print(row_di,row_df)
        sub_buffer=[]
        if row_di[0] == row_df[0] and row_di[1] == row_df[1]:
            #print('ttttt')
            if row_df[4] == str(1) and row_df[3] == str(1) and row_df[2] != str(2013):
                sub_buffer, need_to_continue =write_gap_year(row_df)
                if need_to_continue == 1:
                    continue
                else:
                    buffer.append(sub_buffer)
            if row_df[4] == str(1) and row_df[3] != str(1):
                sub_buffer, need_to_continue =write_gap_month(row_df)
                if need_to_continue == 1:
                    continue
                else:
                    buffer.append(sub_buffer)
            if row_df[4] == str(2):
                sub_buffer, need_to_continue =write_2(row_df)
                if need_to_continue == 1:
                    continue
                else:
                    buffer.append(sub_buffer)
            if row_df[4] == str(3):
                sub_buffer, need_to_continue =write_3(row_df)
                #print(sub_buffer)
                if need_to_continue == 1:
                    continue
                else:
                    buffer.append(sub_buffer)
    
    #print(buffer)
    if buffer !=[]:
        import csv
        filename = ('C:\\Users\\Aaron\\weather\\東方果實蠅'+ buffer[0][0]+ buffer[0][1]+'.csv')
        print(filename)
        with open(filename, "w") as f:
            writer = csv.writer(f)
            writer.writerows(buffer)
        f.close()
# Out:
# C:\Users\Aaron\weather\東方果實蠅台中市石岡區.csv
# C:\Users\Aaron\weather\東方果實蠅台中市后里區.csv
# C:\Users\Aaron\weather\東方果實蠅台中市和平區.csv
# C:\Users\Aaron\weather\東方果實蠅台中市東勢區.csv
# C:\Users\Aaron\weather\東方果實蠅台東縣台東地區.csv
# C:\Users\Aaron\weather\東方果實蠅台南市大內區.csv
# C:\Users\Aaron\weather\東方果實蠅台南市玉井區.csv
# C:\Users\Aaron\weather\東方果實蠅台南市官田區.csv
# C:\Users\Aaron\weather\東方果實蠅台南市東山區.csv
# C:\Users\Aaron\weather\東方果實蠅台南市南化區.csv
# C:\Users\Aaron\weather\東方果實蠅宜蘭縣冬山鄉.csv
# C:\Users\Aaron\weather\東方果實蠅宜蘭縣員山鄉.csv
# C:\Users\Aaron\weather\東方果實蠅宜蘭縣頭城鎮.csv
# C:\Users\Aaron\weather\東方果實蠅花蓮縣玉溪地區.csv
# C:\Users\Aaron\weather\東方果實蠅花蓮縣花蓮市.csv
# C:\Users\Aaron\weather\東方果實蠅花蓮縣富里鄉.csv
# C:\Users\Aaron\weather\東方果實蠅花蓮縣瑞穗鄉.csv
# C:\Users\Aaron\weather\東方果實蠅金門縣金門地區.csv
# C:\Users\Aaron\weather\東方果實蠅南投縣中寮鄉.csv
# C:\Users\Aaron\weather\東方果實蠅南投縣水里鄉.csv
# C:\Users\Aaron\weather\東方果實蠅南投縣埔里鎮.csv
# C:\Users\Aaron\weather\東方果實蠅屏東縣里港鄉.csv
# C:\Users\Aaron\weather\東方果實蠅屏東縣佳冬鄉.csv
# C:\Users\Aaron\weather\東方果實蠅屏東縣枋山地區.csv
# ...

# %%
X,y
