# %%
import csv
import os
from bs4 import BeautifulSoup
import datetime
import time
import urllib
import requests
import socket
import urllib.request,urllib.parse,urllib.error
import random

def read_data():
    with open('地區資訊new.csv', 'r') as f:  #opens PW file
        reader = csv.reader(f)
        di = list(list(rec) for rec in csv.reader(f, delimiter=',')) #reads csv into a list of lists
        f.close()

    with open('蔬果重要害蟲防疫旬報_東方果實蠅數據_new.csv','r') as f:
        reader = csv.reader(f)
        df = list(list(rec) for rec in csv.reader(f, delimiter=','))
        #data_fly
        f.close()
    return di, df

# %%
def write_gap_year(row, year, month, day):
    need_to_continue = 0
    day_10_ago = ((datetime.datetime.now()-datetime.timedelta(days=10)).strftime("%d"))
    
    filename_last_month = 'C:\\Users\Aaron\\weather\\' + row[0] + row[1] + str(int(year)-1) + str(int(month)-1) + '.txt' 
    with open(filename_last_month,'r') as f:
        data = f.read()
        f.close()
    sp = BeautifulSoup(data,'lxml')
    tra = sp.find_all('tr')
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    traa_count=0
    for traa in tra:
        traa_count = traa_count+1
        if traa_count >= int(day_10_ago):
            tda=traa.find_all('td')
            tdaa_count = 0
            for tdaa in tda:
                tdaa_count = tdaa_count +1
                if  tdaa_count == 1:
                    row.append(tdaa.text)
                if  tdaa_count == 8 or tdaa_count==9 or tdaa_count==11 or tdaa_count==18:
                    row.append(tdaa.text.replace('\xa0',''))
                    
    filename_last_month = 'C:\\Users\Aaron\\weather\\' + row[0] + row[1] + year + str(int(month)-1) + '.txt' 
    with open(filename_last_month,'r') as f:
        data = f.read()
        f.close()
    sp = BeautifulSoup(data,'lxml')
    tra = sp.find_all('tr')
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    traa_count=0
    for traa in tra:
        traa_count = traa_count+1
        if traa_count < int(day):
            tda=traa.find_all('td')
            tdaa_count = 0
            for tdaa in tda:
                tdaa_count = tdaa_count +1
                if  tdaa_count == 1:
                    row.append(tdaa.text)
                if  tdaa_count == 8 or tdaa_count==9 or tdaa_count==11 or tdaa_count==18:
                    row.append(tdaa.text.replace('\xa0',''))
    
    print('成功')
    return row, need_to_continue

def write_gap_month(row, year, month, day):
    need_to_continue = 0
    day_10_ago = ((datetime.datetime.now()-datetime.timedelta(days=10)).strftime("%d"))
    
    filename_last_month = 'C:\\Users\Aaron\\weather\\' + row[0] + row[1] + year + str(int(month)-1) + '.txt' 
    with open(filename_last_month,'r') as f:
        data = f.read()
        f.close()
    sp = BeautifulSoup(data,'lxml')
    tra = sp.find_all('tr')
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    traa_count=0
    for traa in tra:
        traa_count = traa_count+1
        if traa_count >= int(day_10_ago):
            tda=traa.find_all('td')
            tdaa_count = 0
            for tdaa in tda:
                tdaa_count = tdaa_count +1
                if  tdaa_count == 1:
                    row.append(tdaa.text)
                if  tdaa_count == 8 or tdaa_count==9 or tdaa_count==11 or tdaa_count==18:
                    row.append(tdaa.text.replace('\xa0',''))
                    
    filename_last_month = 'C:\\Users\Aaron\\weather\\' + row[0] + row[1] + year + str(int(month)-1) + '.txt' 
    with open(filename_last_month,'r') as f:
        data = f.read()
        f.close()
    sp = BeautifulSoup(data,'lxml')
    tra = sp.find_all('tr')
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    traa_count=0
    for traa in tra:
        traa_count = traa_count+1
        if traa_count < int(day):
            tda=traa.find_all('td')
            tdaa_count = 0
            for tdaa in tda:
                tdaa_count = tdaa_count +1
                if  tdaa_count == 1:
                    row.append(tdaa.text)
                if  tdaa_count == 8 or tdaa_count==9 or tdaa_count==11 or tdaa_count==18:
                    row.append(tdaa.text.replace('\xa0',''))
    
    print('成功')
    return row, need_to_continue



def write_day10(row, year, month, day):
    need_to_continue = 0
    filename = 'C:\\Users\Aaron\\weather\\' + row[0] + row[1] + year + month + '.txt' 
    with open(filename,'r') as f:
        data = f.read()
        f.close()
    sp = BeautifulSoup(data,'lxml')
    tra = sp.find_all('tr')
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    tra.remove(tra[0])
    if tra ==[]:
        print('tra=[]')
        need_to_continue = 1
    traa_count=0
    for traa in tra:
        traa_count = traa_count+1
        if traa_count < int(today_date_day) and traa_count>= int(today_date_day)-10 :
            tda=traa.find_all('td')
            tdaa_count = 0
            for tdaa in tda:
                tdaa_count = tdaa_count +1
                if  tdaa_count == 1:
                    row.append(tdaa.text)
                if  tdaa_count == 8 or tdaa_count==9 or tdaa_count==11 or tdaa_count==18:
                    row.append(tdaa.text.replace('\xa0',''))
    print('成功')
    return row, need_to_continue


def today_date():
    import time
    ## dd/mm/yyyy格式
    today_date_year = time.strftime("%Y")
    today_date_month = time.strftime("%m").strip('0')
    today_date_day = time.strftime("%d")
    today_date = today_date_year + today_date_month + today_date_day
    return today_date_year, today_date_month, today_date_day

def update_thi_month_data(row):
    
    today_date_year, today_date_month, today_date_day = today_date()
    filename = ('C:\\Users\\Aaron\\weather\\'+ row[0]+ row[1]+today_date_year+today_date_month+'.txt')
    print(filename)
    
    proxy_support = urllib.request.ProxyHandler({'sock5': 'localhost:1080'})
    opener = urllib.request.build_opener(proxy_support)
    urllib.request.install_opener(opener)
    
    if int(today_date_month) < 10:
        url ='http://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station='+str(row[2])+'&stname='+str(row[5])+'&datepicker='+today_date_year+'-0'+today_date_month  
    else:
        url ='http://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station='+str(row[2])+'&stname='+str(row[5])+'&datepicker='+today_date_year+'-'+today_date_month 
    time.sleep(random.randint(40,45))
    
    try:
        response = urllib.request.urlopen(url)
        html = response.read()
        errorc=0
    except urllib.error.URLError as e:
        if hasattr(e, 'reason'):
            print('We failed to reach a server.')
            print('Reason: ', e.reason)
            errorc=1
            pass
        elif hasattr(e, 'code'):
            print('The server couldn\'t fulfill the request.')
            print('Error code: ', e.code)
            errorc=1
            pass
    else:
        print('everything is fine')
                
    if errorc==0:
        filename = 'C:\\Users\\Aaron\\weather\\' + str(row[0]) + str(row[1]) + str(today_date_year) + str(today_date_month) + '.txt'
        with open(filename, 'w') as f:
            f.write(str(html))
            f.close()
        time.sleep(random.randint(4,14))
    else:
        time.sleep(random.randint(1,4))
print('完成')
# Out:
# 完成

# %% [markdown]
# ### 每天早上更新資料

# %%
coun_di = 0
di, df = read_data()
di = di[1:]
data = di

buffer = []
for row_data in data:
    coun_di = coun_di + 1
    today_date_year, today_date_month, today_date_day = today_date()
    row_data = row_data[:2]

    #print(row_di,row_df)
    sub_buffer=[]
    if 'happy' == 'happy':
        #print('ttttt')
        if int(today_date_day) > 10:
            sub_buffer, need_to_continue =write_day10(row_data, today_date_year, today_date_month, today_date_day)
            if need_to_continue == 1:
                continue
            else:
                buffer.append(sub_buffer)
        if int(today_date_day) < 10 and int(today_date_month) != 1:
            sub_buffer, need_to_continue =write_gap_month(row_data, today_date_year, today_date_month, today_date_day)
            if need_to_continue == 1:
                continue
            else:
                buffer.append(sub_buffer)
        if int(today_date_day) < 10 and int(today_date_month) == 1:
            sub_buffer, need_to_continue =write_gap_year(row_data, today_date_year, today_date_month, today_date_day)
            if need_to_continue == 1:
                continue
            else:
                buffer.append(sub_buffer)
        print(sub_buffer)
    break
# Out:
# 成功
# ['台中市', '石岡區', '19', '25.6', '31.0', '22.8', '300', '20', '26.4', '32.1', '21.7', '136', '21', '27.5', '32.2', '23.7', '304', '22', '28.0', '', '', '300', '23', '27.9', '', '', '13', '24', '28.1', '32.4', '24.5', '307', '25', '28.1', '32.4', '24.7', '299', '26', '28.1', '32.9', '24.3', '306', '27', '27.8', '32.6', '23.5', '307']

# %%
di, df = read_data()
di = di[1:]
data = df[1:]
count = 0
for row_di in di:
    count = count+1
    if count == 4 or count > 5:
        update_thi_month_data(row_di)
        time.sleep(60)
# Out:
# C:\Users\Aaron\weather\台中市東勢區20168.txt
# everything is fine
# C:\Users\Aaron\weather\台南市大內區20168.txt
# everything is fine
# C:\Users\Aaron\weather\台南市玉井區20168.txt
# everything is fine
# C:\Users\Aaron\weather\台南市官田區20168.txt
# everything is fine
# C:\Users\Aaron\weather\台南市東山區20168.txt
# everything is fine
# C:\Users\Aaron\weather\台南市南化區20168.txt
# everything is fine
# C:\Users\Aaron\weather\宜蘭縣冬山鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\宜蘭縣員山鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\宜蘭縣頭城鎮20168.txt
# everything is fine
# C:\Users\Aaron\weather\花蓮縣玉溪地區20168.txt
# everything is fine
# C:\Users\Aaron\weather\花蓮縣花蓮市20168.txt
# everything is fine
# C:\Users\Aaron\weather\花蓮縣富里鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\花蓮縣瑞穗鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\金門縣金門地區20168.txt
# everything is fine
# C:\Users\Aaron\weather\南投縣中寮鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\南投縣水里鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\南投縣埔里鎮20168.txt
# everything is fine
# C:\Users\Aaron\weather\屏東縣里港鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\屏東縣佳冬鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\屏東縣枋山地區20168.txt
# everything is fine
# C:\Users\Aaron\weather\屏東縣枋寮地區20168.txt
# everything is fine
# C:\Users\Aaron\weather\屏東縣長治鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\屏東縣高樹鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\屏東縣麟洛鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\苗栗縣三灣鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\苗栗縣公館鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\苗栗縣卓蘭鎮20168.txt
# everything is fine
# C:\Users\Aaron\weather\桃園市大溪區20168.txt
# everything is fine
# C:\Users\Aaron\weather\桃園市復興區20168.txt
# everything is fine
# C:\Users\Aaron\weather\桃園市龍潭區20168.txt
# everything is fine
# C:\Users\Aaron\weather\高雄市大社區20168.txt
# everything is fine
# C:\Users\Aaron\weather\高雄市六龜區20168.txt
# everything is fine
# C:\Users\Aaron\weather\高雄市田寮區20168.txt
# everything is fine
# C:\Users\Aaron\weather\高雄市杉林區20168.txt
# everything is fine
# C:\Users\Aaron\weather\高雄市阿蓮區20168.txt
# everything is fine
# C:\Users\Aaron\weather\高雄市旗山區20168.txt
# everything is fine
# C:\Users\Aaron\weather\高雄市燕巢區20168.txt
# everything is fine
# C:\Users\Aaron\weather\雲林縣斗六市20168.txt
# everything is fine
# C:\Users\Aaron\weather\雲林縣古坑鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\雲林縣林內鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\新竹縣北埔鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\新竹縣芎林鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\新竹縣峨眉鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\新竹縣新埔鎮20168.txt
# everything is fine
# C:\Users\Aaron\weather\新竹縣關西鎮20168.txt
# everything is fine
# C:\Users\Aaron\weather\嘉義縣中埔鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\嘉義縣竹崎鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\嘉義縣梅山鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\嘉義縣番路鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\嘉義縣義竹鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\彰化縣二林鎮20168.txt
# everything is fine
# C:\Users\Aaron\weather\彰化縣社頭鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\彰化縣花壇鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\彰化縣員林市20168.txt
# everything is fine
# C:\Users\Aaron\weather\彰化縣溪州鄉20168.txt
# everything is fine
# C:\Users\Aaron\weather\澎湖縣澎湖地區20168.txt
# everything is fine
